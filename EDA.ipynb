# %% [markdown]
# # Initialization

# %%
# Loading libraries

import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ## Load Data

# %%
# load *.csv file into dataframes

try:
    vehicles_df = pd.read_csv('vehicles_us.csv')
except:
    vehicles_df = pd.read_csv('https://practicum-content.s3.us-west-1.amazonaws.com/datasets/vehicles_us.csv')

# %% [markdown]
# # EDA - Exploratory Data Analysis
#
# <u>OBJECTIVE</u>
# 1. Review uploaded vehicles_us.csv file
# 2. Check for missing values/Nulls, NaN (*Not a Number, etc.*)
#
# <br>
#
# <u>Findings / Observations</u>
# - 51525 row with 13 columns
# - missing values, nulls, & NaNs found in the following attributes
#     1. model_year (3619)
#     2. cylinders (5260)
#     3. odometer (7892)
#     4. paint_color (9267)
#     5. is_4wd (25953)
# - <>
#
# <br>
#
# <u>Note-2-Self</u>
# - <>

# %%
# EDA - preview data

display(vehicles_df.sample(50))
# Out:
#        price  model_year                          model  condition  cylinders  \
# 23159  15250      2010.0                     ford f-150  excellent        NaN
# 49799   6000      1998.0                  jeep wrangler       good        NaN
# 32848   3100      2002.0            chevrolet silverado       fair        NaN
# 18182  32990      2016.0                  ford f-250 sd       good        8.0
# 2870    7894      2012.0                    ford escape       good        6.0
# 19198  24500      2014.0       chevrolet silverado 1500  excellent        8.0
# 22212  18588      2013.0            chevrolet silverado   like new        8.0
# 17534   7499         NaN              volkswagen passat   like new        NaN
# 30022   5000         NaN               chevrolet impala       good        6.0
# 5132   19985      2007.0                       ram 2500  excellent        6.0
# 8303   13400         NaN              chevrolet equinox  excellent        4.0
# 39336   4900      2012.0                   toyota camry       fair        4.0
# 51260   2900      2005.0                  toyota sienna       good        6.0
# 49594   7000      2007.0       chevrolet silverado 1500       good        6.0
# 45773   4500      2003.0     chevrolet silverado 2500hd  excellent        8.0
# 17194   5300      2009.0                      ford edge  excellent        6.0
# 331    11295      2015.0                  nissan altima  excellent        4.0
# 5897    3995      2012.0                   chrysler 200  excellent        4.0
# 12520   5600      2008.0                  ford explorer  excellent        6.0
# 35027   7757      2011.0                    ford escape  excellent        6.0
# 21512  22499      2017.0                  buick enclave  excellent        6.0
# 50277  16995      2011.0     chevrolet silverado 2500hd   like new        8.0
# 25451  22988      2014.0                  jeep wrangler   like new        NaN
# 28873  29588      2017.0            chevrolet silverado   like new        8.0
# 49864  10995      2011.0                         bmw x5  excellent        6.0
# 26570   9495      2013.0                   chrysler 200  excellent        4.0
# 40876   4670      2003.0                       ram 1500  excellent        8.0
# 39881  14950      2014.0                      ford f150  excellent        6.0
# 40512   4995         NaN               chevrolet malibu  excellent        NaN
# 120    33900      2018.0  chevrolet silverado 1500 crew       good        8.0
# 25320   2995      2008.0                 subaru impreza  excellent        4.0
# 47749   2750      2004.0                  nissan sentra  excellent        4.0
# 17498   9998      2012.0                   jeep liberty  excellent        6.0
# 25134  13900      2007.0                      ford f250       good        8.0
# 22469  14500      2003.0           ford f250 super duty       good        8.0
# 1656   21988      2012.0                 toyota 4runner   like new        6.0
# 17257   4350      2012.0                     honda cr-v       fair        4.0
# 34347  16988      2011.0                  jeep wrangler   like new        6.0
# 43352   6995      2015.0                    ford fusion       good        4.0
# 6534    5695      2012.0                     ford focus       good        4.0
# 41309  10500      2006.0                 toyota 4runner  excellent        6.0
# 4590    4000      2009.0                   toyota camry       good        4.0
# 51345   2000      2005.0                   honda accord       good        4.0
# 42078   7000      2014.0              volkswagen passat       good        4.0
# 48330  15500      2016.0                   honda accord  excellent        4.0
# 29282  14700      2017.0               chevrolet malibu  excellent        4.0
# 15809  22988      2014.0                       ram 1500   like new        8.0
# 29016  22100      2013.0    ford f150 supercrew cab xlt       good        6.0
# 39217   5950      2012.0                 subaru outback       good        4.0
# 16811   8900      2011.0                     honda cr-v  excellent        4.0
#
#          fuel  odometer transmission    type paint_color  is_4wd date_posted  \
# 23159     gas       NaN    automatic  pickup       white     1.0  2018-10-17
# 49799     gas   90500.0       manual     SUV      purple     1.0  2018-11-10
# 32848     gas  117000.0    automatic  pickup       green     1.0  2018-12-28
# 18182     gas    5031.0    automatic   truck       black     1.0  2018-12-29
# 2870      gas       NaN    automatic     SUV         NaN     1.0  2018-08-26
# 19198     gas   90000.0    automatic   truck       black     1.0  2018-06-17
# 22212     gas  101000.0    automatic   truck         NaN     1.0  2018-11-19
# 17534     gas   63093.0    automatic   sedan         NaN     NaN  2019-03-13
# 30022     gas       NaN    automatic   sedan       black     NaN  2018-07-19
# 5132   diesel       NaN    automatic  pickup         NaN     1.0  2018-08-05
# 8303      gas  104251.0    automatic     SUV       white     1.0  2018-09-13
# 39336     gas       NaN    automatic   sedan         NaN     NaN  2018-05-27
# 51260     gas  283771.0    automatic   wagon      yellow     NaN  2018-05-02
# 49594     gas  114000.0    automatic  pickup         red     NaN  2018-09-07
# 45773  diesel  237466.0    automatic   truck        grey     NaN  2018-08-30
# 17194     gas       NaN    automatic     SUV       white     NaN  2018-08-10
# 331       gas   80148.0    automatic   sedan         NaN     NaN  2018-08-16
# 5897      gas  198000.0    automatic   sedan         NaN     NaN  2019-01-09
# 12520     gas  128160.0    automatic     SUV       white     NaN  2018-12-01
# 35027     gas  128046.0    automatic     SUV        blue     1.0  2019-03-29
# 21512     gas   18742.0    automatic     SUV      silver     NaN  2018-07-14
# 50277     gas  180995.0    automatic   truck       white     1.0  2018-08-27
# 25451     gas   84494.0    automatic     SUV       black     1.0  2018-08-01
# 28873     gas   17000.0    automatic   truck        grey     1.0  2019-01-18
# 49864     gas  114000.0    automatic     SUV      silver     1.0  2019-01-29
# 26570     gas   70719.0    automatic   sedan       white     NaN  2018-07-20
# 40876     gas  192000.0    automatic   truck       white     1.0  2018-06-04
# 39881     gas   46297.0    automatic  pickup         NaN     NaN  2018-10-20
# 40512     gas   78000.0    automatic   sedan        grey     NaN  2018-05-04
# 120       gas   11315.0        other  pickup       white     1.0  2019-03-01
# 25320     gas  141337.0    automatic   sedan       black     1.0  2019-01-29
# 47749     gas  151000.0       manual   sedan      silver     NaN  2018-10-18
# 17498     gas   85156.0    automatic     SUV      silver     1.0  2018-09-08
# 25134  diesel  180441.0    automatic   truck         red     1.0  2019-01-15
# 22469  diesel       NaN       manual   truck       white     1.0  2018-11-26
# 1656      gas   81378.0    automatic     SUV        grey     1.0  2018-10-28
# 17257     gas  139618.0    automatic     SUV         NaN     1.0  2018-08-31
# 34347     gas       NaN    automatic     SUV       white     1.0  2019-01-01
# 43352     gas   76300.0    automatic   sedan       black     NaN  2019-01-22
# 6534      gas  100800.0    automatic   sedan         red     NaN  2019-03-13
# 41309     gas       NaN    automatic     SUV      silver     1.0  2019-01-29
# 4590      gas  233897.0    automatic   sedan       white     NaN  2018-12-03
# 51345     gas  201398.0    automatic   sedan        grey     NaN  2018-05-02
# 42078     gas   72000.0    automatic   sedan       white     NaN  2018-10-18
# 48330     gas   55863.0    automatic   coupe         NaN     NaN  2019-01-06
# 29282     gas   23521.0    automatic   sedan        blue     NaN  2019-02-04
# 15809     gas   75000.0    automatic   truck       black     1.0  2018-12-13
# 29016     gas   80854.0        other  pickup       white     1.0  2018-09-14
# 39217     gas  208100.0    automatic   wagon         NaN     1.0  2018-11-15
# 16811     gas  117000.0    automatic     SUV       brown     1.0  2018-05-12
#
#        days_listed
# 23159            3
# 49799           23
# 32848           52
# 18182           69
# 2870            15
# 19198           19
# 22212           37
# 17534           21
# 30022           38
# 5132            32
# 8303             7
# 39336           17
# 51260           61
# 49594          108
# 45773           16
# 17194           16
# 331             35
# 5897            54
# 12520           41
# 35027           39
# 21512           51
# 50277           56
# 25451           27
# 28873            4
# 49864           22
# 26570           60
# 40876           22
# 39881           92
# 40512           15
# 120              2
# 25320           40
# 47749           78
# 17498            3
# 25134           52
# 22469           10
# 1656            12
# 17257           66
# 34347           72
# 43352           38
# 6534           105
# 41309          105
# 4590            33
# 51345           93
# 42078           34
# 48330            5
# 29282           35
# 15809            6
# 29016           24
# 39217           67
# 16811           40

# %%
# EDA - check for nulls/NaN/missing values

# view & identify dataframe attributes with null/missing values
vehicles_df.info()
print('\n\n')

# counts of missing values, nulls, NaNs
print('Missing Value / Null / NaN Counts')
display(vehicles_df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
#
#
#
# Missing Value / Null / NaN Counts
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %%
# EDA -

# %%
#

vehicles_df.value_counts())
# Out:
#   Cell In[38], line 3
#     vehicles_df.value_counts())
#                               ^
# SyntaxError: unmatched ')'

# %%
# Feature Engineering - parse manufacturer and model name in 'model' column
# code to reference to parse manufacturer and model
# use later.  Need to clean.
# remove null / Nan / missing values


#vehicles_df[['make', 'model']] = vehicles_df['model'].str.split(' ', n=1, expand=True)
