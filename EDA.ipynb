# %%
# imported libaries

import pandas as pd
import numpy as np
import plotly.express as px

# %%
# read vehicles.csv

try:
    vehicles_df = pd.read_csv('vehicles_us.csv')
except:
    vehicles_df = pd.read_csv('https://practicum-content.s3.us-west-1.amazonaws.com/datasets/vehicles_us.csv')

# %%
# PREVIEW DATA

display(vehicles_df.sample(20))
# Out:
#        price  model_year                       model  condition  cylinders  \
# 48497   2500      2003.0                ford mustang       good        8.0
# 24743  33500      2018.0  chevrolet silverado 2500hd       good        8.0
# 16494  16999      2012.0                    ram 1500  excellent        8.0
# 19175   3995      2005.0                dodge dakota  excellent        6.0
# 26200   3995      2000.0                honda accord  excellent        4.0
# 3887    6900      2013.0                  ford focus       good        4.0
# 13389   6900      2012.0                chrysler 200  excellent        4.0
# 24827   5000      2009.0              subaru outback       fair        4.0
# 16096   3000      2001.0                 ford ranger       good        6.0
# 30437   7500      2004.0                    ram 2500       good        8.0
# 36422   7500      2015.0              hyundai sonata       good        NaN
# 46300  22990      2007.0  chevrolet silverado 3500hd       good        8.0
# 33001  21500      2008.0                   ford f250  excellent        8.0
# 28020   8500      2008.0              toyota 4runner   like new        6.0
# 24291   9500         NaN                  ford f-150       good        8.0
# 16870      1      2014.0            chevrolet camaro  excellent        8.0
# 46635  19995      2014.0    chevrolet silverado 1500  excellent        8.0
# 21126   4250      2010.0            chevrolet malibu  excellent        4.0
# 33145  42933      2016.0                   gmc yukon  excellent        8.0
# 14799  19995      2015.0                    ram 1500   like new        8.0
#
#          fuel  odometer transmission       type paint_color  is_4wd  \
# 48497     gas  176824.0       manual      coupe      silver     NaN
# 24743     gas   25401.0    automatic      truck       white     1.0
# 16494     gas  106610.0    automatic     pickup       black     NaN
# 19175     gas  140605.0    automatic     pickup        blue     1.0
# 26200     gas  176202.0    automatic      sedan        blue     NaN
# 3887      gas   81611.0    automatic      sedan         red     NaN
# 13389     gas       NaN    automatic      sedan       white     NaN
# 24827     gas  152000.0    automatic  hatchback       black     1.0
# 16096     gas       NaN    automatic     pickup       black     1.0
# 30437  diesel  217000.0    automatic      truck       black     1.0
# 36422     gas       NaN    automatic      sedan         NaN     NaN
# 46300     gas   64185.0    automatic      truck         NaN     1.0
# 33001  diesel   93000.0    automatic      truck       white     1.0
# 28020     gas  211814.0    automatic        SUV         NaN     NaN
# 24291  hybrid   99000.0    automatic     pickup         NaN     1.0
# 16870     gas   51550.0       manual      coupe       black     1.0
# 46635     gas  112000.0    automatic      truck         red     1.0
# 21126     gas       NaN    automatic      sedan       white     NaN
# 33145     gas   34229.0    automatic        SUV         NaN     1.0
# 14799     gas   55000.0    automatic     pickup       white     NaN
#
#       date_posted  days_listed
# 48497  2018-07-13           16
# 24743  2018-08-14           69
# 16494  2019-03-12            1
# 19175  2018-07-08           37
# 26200  2019-03-06           14
# 3887   2018-08-04           24
# 13389  2019-01-02           31
# 24827  2018-11-27           47
# 16096  2019-03-09            8
# 30437  2018-08-14           17
# 36422  2018-05-16           88
# 46300  2018-09-17           87
# 33001  2019-02-04           26
# 28020  2018-05-12           73
# 24291  2018-09-08           23
# 16870  2018-12-15            7
# 46635  2019-02-09           37
# 21126  2019-03-03           15
# 33145  2019-04-18           40
# 14799  2019-01-25           81

# %%
# EDA - check for nulls/NaN/missing values

vehicles_df.info()
print('\n\n')


print('Missing Values')
vehicles_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
#
#
#
# Missing Values
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %%
#

vehicles_df.isna().sum()

# %%
#

vehicles_df.value_counts())
# Out:
# price   model_year  model            condition  cylinders  fuel    odometer  transmission  type    paint_color  is_4wd  date_posted  days_listed
# 1       1997.0      ford f350        good       8.0        diesel  300000.0  automatic     truck   white        1.0     2019-01-22   51             1
# 18490   2015.0      ford f-250 sd    good       8.0        gas     124332.0  automatic     truck   white        1.0     2018-07-23   25             1
# 18400   2005.0      ford f250        good       8.0        diesel  206321.0  automatic     pickup  white        1.0     2018-06-10   53             1
#         2011.0      ram 1500         excellent  8.0        gas     66508.0   automatic     truck   silver       1.0     2018-09-06   31             1
#         2015.0      ram 1500         excellent  8.0        gas     70000.0   automatic     truck   black        1.0     2019-03-06   117            1
#                                                                                                                                                    ..
# 8950    2010.0      ford f-150       excellent  8.0        gas     169000.0  automatic     truck   silver       1.0     2019-03-04   22             1
#                                      good       8.0        gas     225643.0  automatic     truck   silver       1.0     2018-12-14   20             1
#                     subaru forester  excellent  4.0        gas     75668.0   automatic     SUV     blue         1.0     2018-10-21   1              1
#         2011.0      subaru forester  excellent  4.0        gas     97285.0   automatic     SUV     grey         1.0     2019-04-12   13             1
# 375000  1999.0      nissan frontier  good       6.0        gas     115000.0  automatic     pickup  blue         1.0     2018-05-19   21             1
# Name: count, Length: 14852, dtype: int64

# %%
# code to reference to parse manufacturer and model
# use later.  Need to clean.
# remove null / Nan / missing values


#vehicles_df[['make', 'model']] = vehicles_df['model'].str.split(' ', n=1, expand=True)
